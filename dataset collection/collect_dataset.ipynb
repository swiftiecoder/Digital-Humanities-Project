# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import json

# %%
awards = pd.read_csv("awards-information.csv").drop(["Network"], axis=1)
awards["Date"] = pd.to_datetime(awards["Date"]).apply(lambda x: x.year-1)
awards = awards[(awards["Date"] > 1959) & (awards["Date"] < 2024)]
awards.reset_index(inplace=True, drop=True)

# %%
awards.head()
# Out:
#   Edition  Date
# 0     3rd  1960
# 1     4th  1961
# 2     5th  1962
# 3     6th  1963
# 4     7th  1964

# %%
def get_url(edition, year):
    if year < 2017:
        return f"https://www.grammy.com/awards/{edition}-annual-grammy-awards" 
    else:   
        return f"https://www.grammy.com/awards/{edition}-annual-grammy-awards-{year}"

# %%
awards['url'] = awards.apply(lambda row: get_url(row['Edition'], row['Date']), axis=1)

# %%
awards.head()
# Out:
#   Edition  Date                                                url
# 0     3rd  1960  https://www.grammy.com/awards/3rd-annual-gramm...
# 1     4th  1961  https://www.grammy.com/awards/4th-annual-gramm...
# 2     5th  1962  https://www.grammy.com/awards/5th-annual-gramm...
# 3     6th  1963  https://www.grammy.com/awards/6th-annual-gramm...
# 4     7th  1964  https://www.grammy.com/awards/7th-annual-gramm...

# %%
test = awards["url"][0]
test
# Out:
# 'https://www.grammy.com/awards/3rd-annual-grammy-awards'

# %%
awards.tail(5)
# Out:
#    Edition  Date                                                url
# 59    62nd  2019  https://www.grammy.com/awards/62nd-annual-gram...
# 60    63rd  2020  https://www.grammy.com/awards/63rd-annual-gram...
# 61    64th  2021  https://www.grammy.com/awards/64th-annual-gram...
# 62    65th  2022  https://www.grammy.com/awards/65th-annual-gram...
# 63    66th  2023  https://www.grammy.com/awards/66th-annual-gram...

# %%
test = awards["url"][58]

# %%
awards["url"][63]
# Out:
# 'https://www.grammy.com/awards/66th-annual-grammy-awards-2023'

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page you want to scrape
url = test

# Send a request to the page
response = requests.get(url)

# Create a BeautifulSoup object and specify the parser
soup = BeautifulSoup(response.content, 'html.parser')

# %%
data = soup.find('script', id="__NEXT_DATA__" ,type="application/json")
data = json.loads(data.string)

# %%
categories = data["props"]["pageProps"]["pageContent"]["getAwardsYears"]["hits"][0]["categoryDetails"]

# Could use to get show year
print(data["props"]["pageProps"]["pageContent"]["getAwardsYears"]["hits"][0]["showYear"])
# Out:
# 2018

# %%
info = None
for category in categories:
    if "song of the year" in category["title"][0]['name'].lower():
        info = category["nominations"]
        break

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
data = soup.find('script', id="__NEXT_DATA__" ,type="application/json")
data = json.loads(data.string)
categories = data["props"]["pageProps"]["pageContent"]["getAwardsYears"]["hits"][0]["categoryDetails"]
info = None
for category in categories:
    if "song of the year" in category["title"][0]['name'].lower():
        info = category["nominations"]
        break

# %%
info
# Out:
# [{'__typename': 'Nominations',
#   'title': 'This Is America',
#   'isWinner': True,
#   'nomineeOrder': 8,
#   'displayLine1': '"This Is America"',
#   'displayLine2': '',
#   'displayLine3': 'Donald Glover, Ludwig Göransson & Jeffery Lamar Williams, songwriters (Childish Gambino)',
#   'creditedArtists': [{'__typename': 'Artist',
#     'title': 'Childish Gambino',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/childish-gambino/18365',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Childish Gambino',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Ludwig Goransson',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/ludwig-goransson/187476',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Ludwig Goransson',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Jeffery Lamar Williams',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/jeffery-lamar-williams/245883',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0002068342',
#      'titleField': 'Jeffery Lamar Williams',
#      'damDynamic': 'https://i8.amplience.net/i/naras/jeffery-lamar-williams_MI0004743347-MN0002068342',
#      'damThumbnail': 'https://thumbs.amplience.net/r/d1a71c37-e335-4363-b938-ccb4e86f1cb0',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 760,
#       'height': 998,
#       'format': 'JPEG',
#       'status': 'ok'}}}]},
#  {'__typename': 'Nominations',
#   'title': 'Shallow',
#   'isWinner': False,
#   'nomineeOrder': 7,
#   'displayLine1': '"Shallow"',
#   'displayLine2': '',
#   'displayLine3': 'Lady Gaga, Mark Ronson, Anthony Rossomando & Andrew Wyatt, songwriters (Lady Gaga & Bradley Cooper)',
#   'creditedArtists': [{'__typename': 'Artist',
#     'title': 'Lady Gaga',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/lady-gaga/3611',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0000994823',
#      'titleField': 'Lady Gaga',
#      'damDynamic': 'https://i8.amplience.net/i/naras/MI0005298282-MN0000994823',
#      'damThumbnail': 'https://thumbs.amplience.net/r/56acaf7d-f4a9-46ee-add2-8663d44b80bb',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 1000,
#       'height': 1000,
#       'format': 'JPEG',
#       'status': 'ok'}}},
#    {'__typename': 'Artist',
#     'title': 'Mark Ronson',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/mark-ronson/17323',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0000237773',
#      'titleField': 'Mark Ronson',
#      'damDynamic': 'https://i8.amplience.net/i/naras/mark-ronson_MI0003809882-MN0000237773',
#      'damThumbnail': 'https://thumbs.amplience.net/r/a41545e5-122a-4495-9801-c9ed603fd286',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 1500,
#       'height': 1500,
#       'format': 'JPEG',
#       'status': 'ok'}}},
#    {'__typename': 'Artist',
#     'title': 'Anthony Rossomando',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/anthony-rossomando/243511',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Anthony Rossomando',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Andrew Wyatt',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/andrew-wyatt/12906',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Andrew Wyatt',
#      'damDynamic': None,
#      'damThumbnail': None}}]},
#  {'__typename': 'Nominations',
#   'title': 'The Middle',
#   'isWinner': False,
#   'nomineeOrder': 6,
#   'displayLine1': '"The Middle"',
#   'displayLine2': '',
#   'displayLine3': 'Sarah Aarons, Jordan K. Johnson, Stefan Johnson, Marcus Lomax, Kyle Trewartha, Michael Trewartha & Anton Zaslavski, songwriters (Zedd, Maren Morris & Grey)',
#   'creditedArtists': [{'__typename': 'Artist',
#     'title': 'Sarah Aarons',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/sarah-aarons/243108',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Sarah Aarons',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Jordan K. Johnson',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/jordan-k-johnson/243330',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Jordan K. Johnson',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Stefan Johnson',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/stefan-johnson/243331',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Stefan Johnson',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Marcus Lomax',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/marcus-lomax/243378',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Marcus Lomax',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Kyle Trewartha',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/kyle-trewartha/243576',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Kyle Trewartha',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Michael Trewartha',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/michael-trewartha/243577',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Michael Trewartha',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Zedd',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/zedd/18186',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0002782403',
#      'titleField': 'Zedd',
#      'damDynamic': 'https://i8.amplience.net/i/naras/zedd_MI0003861631-MN0002782403',
#      'damThumbnail': 'https://thumbs.amplience.net/r/94c38c82-8982-411b-9217-b8c6e6c1283f',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 2048,
#       'height': 2048,
#       'format': 'JPEG',
#       'status': 'ok'}}}]},
#  {'__typename': 'Nominations',
#   'title': 'The Joke',
#   'isWinner': False,
#   'nomineeOrder': 5,
#   'displayLine1': '"The Joke"',
#   'displayLine2': '',
#   'displayLine3': 'Brandi Carlile, Dave Cobb, Phil Hanseroth & Tim Hanseroth, songwriters (Brandi Carlile)',
#   'creditedArtists': [{'__typename': 'Artist',
#     'title': 'Brandi Carlile',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/brandi-carlile/18940',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0000376793',
#      'titleField': 'Brandi Carlile',
#      'damDynamic': 'https://i8.amplience.net/i/naras/brandi-carlile_MI0005353294-MN0000376793',
#      'damThumbnail': 'https://thumbs.amplience.net/r/69286ebb-b770-493c-b3ae-bb9c209a96b4',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 2477,
#       'height': 3302,
#       'format': 'JPEG',
#       'status': 'ok'}}},
#    {'__typename': 'Artist',
#     'title': 'Dave Cobb',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/dave-cobb/18959',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Dave Cobb',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Phil Hanseroth',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/phil-hanseroth/243282',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Phil Hanseroth',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Tim Hanseroth',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/tim-hanseroth/243283',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Tim Hanseroth',
#      'damDynamic': None,
#      'damThumbnail': None}}]},
#  {'__typename': 'Nominations',
#   'title': 'In My Blood',
#   'isWinner': False,
#   'nomineeOrder': 4,
#   'displayLine1': '"In My Blood"',
#   'displayLine2': '',
#   'displayLine3': 'Teddy Geiger, Scott Harris, Shawn Mendes & Geoffrey Warburton, songwriters (Shawn Mendes)',
#   'creditedArtists': [{'__typename': 'Artist',
#     'title': 'Teddy Geiger',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/teddy-geiger/243253',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0000895677',
#      'titleField': 'Teddy Geiger',
#      'damDynamic': 'https://i8.amplience.net/i/naras/teddy-geiger_MI0004808867-MN0000895677',
#      'damThumbnail': 'https://thumbs.amplience.net/r/f08462a8-e04b-4138-b991-8251b08dd4e1',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 5760,
#       'height': 3840,
#       'format': 'JPEG',
#       'status': 'ok'}}},
#    {'__typename': 'Artist',
#     'title': 'Scott Harris',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/scott-harris/243287',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Scott Harris',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Shawn Mendes',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/shawn-mendes/243416',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0003276902',
#      'titleField': 'Shawn Mendes',
#      'damDynamic': 'https://i8.amplience.net/i/naras/shawn-mendes_MI0005483779-MN0003276902',
#      'damThumbnail': 'https://thumbs.amplience.net/r/9b56f170-0161-4124-b766-850491335127',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 1000,
#       'height': 1000,
#       'format': 'JPEG',
#       'status': 'ok'}}},
#    {'__typename': 'Artist',
#     'title': 'Geoffrey Warburton',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/geoffrey-warburton/243593',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Geoffrey Warburton',
#      'damDynamic': None,
#      'damThumbnail': None}}]},
#  {'__typename': 'Nominations',
#   'title': "God's Plan",
#   'isWinner': False,
#   'nomineeOrder': 3,
#   'displayLine1': '"God\'s Plan"',
#   'displayLine2': '',
#   'displayLine3': 'Aubrey Graham, Daveon Jackson, Brock Korsan, Ron LaTour, Matthew Samuels & Noah Shebib, songwriters (Drake)',
#   'creditedArtists': [{'__typename': 'Artist',
#     'title': 'Drake',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/drake/12370',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0001035294',
#      'titleField': 'Drake',
#      'damDynamic': 'https://i8.amplience.net/i/naras/drake_MI0005316097-MN0001035294',
#      'damThumbnail': 'https://thumbs.amplience.net/r/954abc31-976c-480e-8eac-d88aa69e3657',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 1600,
#       'height': 900,
#       'format': 'JPEG',
#       'status': 'ok'}}},
#    {'__typename': 'Artist',
#     'title': 'Daveon Jackson',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/Daveon-Jackson/34480',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Daveon Jackson',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Brock Korsan',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/brock-korsan/243362',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Brock Korsan',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Cardo',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/cardo/19603',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Cardo',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Matthew Samuels',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/matthew-samuels/13836',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Matthew Samuels',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Noah "40" Shebib',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/noah-40-shebib/6134',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Noah "40" Shebib',
#      'damDynamic': None,
#      'damThumbnail': None}}]},
#  {'__typename': 'Nominations',
#   'title': "Boo'd Up",
#   'isWinner': False,
#   'nomineeOrder': 2,
#   'displayLine1': '"Boo\'d Up"',
#   'displayLine2': '',
#   'displayLine3': 'Roderick Pusharod Bullock, Larrance Dopson, Joelle James, Ella Mai & Dijon McFarlane, songwriters (Ella Mai)',
#   'creditedArtists': [{'__typename': 'Artist',
#     'title': 'Roderick Pusharod Bullock',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/roderick-pusharod-bullock/52455',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': '',
#      'titleField': 'Roderick Pusharod Bullock',
#      'damDynamic': '',
#      'damThumbnail': ''}},
#    {'__typename': 'Artist',
#     'title': 'Larrance Dopson',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/larrance-dopson/1867',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Larrance Dopson',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Joelle James',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/joelle-james/243323',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0003463426',
#      'titleField': 'Joelle James',
#      'damDynamic': 'https://i8.amplience.net/i/naras/joelle-james_MI0004239084-MN0003463426',
#      'damThumbnail': 'https://thumbs.amplience.net/r/cf2a7e88-e746-42c1-8c94-a43425fe30d1',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 1024,
#       'height': 1019,
#       'format': 'JPEG',
#       'status': 'ok'}}},
#    {'__typename': 'Artist',
#     'title': 'Ella Mai',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/ella-mai/243383',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Ella Mai',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Dijon McFarlane',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/dijon-mcfarlane/243405',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Dijon McFarlane',
#      'damDynamic': None,
#      'damThumbnail': None}}]},
#  {'__typename': 'Nominations',
#   'title': 'All The Stars',
#   'isWinner': False,
#   'nomineeOrder': 1,
#   'displayLine1': '"All The Stars"',
#   'displayLine2': '',
#   'displayLine3': 'Kendrick Duckworth, Solána Rowe, Al Shuckburgh, Mark Spears & Anthony Tiffith, songwriters (Kendrick Lamar & SZA)',
#   'creditedArtists': [{'__typename': 'Artist',
#     'title': 'Kendrick Lamar',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/kendrick-lamar/17949',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0002709646',
#      'titleField': 'Kendrick Lamar',
#      'damDynamic': 'https://i8.amplience.net/i/naras/MI0004224402-MN0002709646',
#      'damThumbnail': 'https://thumbs.amplience.net/r/8aaf396c-bf67-413e-8a88-85cef21e083c',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 500,
#       'height': 500,
#       'format': 'JPEG',
#       'status': 'ok'}}},
#    {'__typename': 'Artist',
#     'title': 'SZA',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Tivo',
#     'manualImage': '',
#     'slug': 'artists/Solana-Rowe/32514',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': 'MN0003180568',
#      'titleField': 'SZA',
#      'damDynamic': 'https://i8.amplience.net/i/naras/MI0005727477-MN0003180568',
#      'damThumbnail': 'https://thumbs.amplience.net/r/4d445c1f-3dbb-400e-8547-3a53a4881a6b',
#      'poi': {'isImage': True,
#       'alpha': False,
#       'width': 1080,
#       'height': 1000,
#       'format': 'JPEG',
#       'status': 'ok'}}},
#    {'__typename': 'Artist',
#     'title': 'Alexander Shuckburgh',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/alexander-shuckburgh/6189',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Alexander Shuckburgh',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'Sounwave',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/sounwave/18126',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'Sounwave',
#      'damDynamic': None,
#      'damThumbnail': None}},
#    {'__typename': 'Artist',
#     'title': 'A. Tiffith',
#     'creditedAs': 'Songwriter',
#     'imageType': 'Default',
#     'manualImage': '',
#     'slug': 'artists/tiffith/188771',
#     'tivoInfo': {'__typename': 'TivoInfo',
#      'idField': None,
#      'titleField': 'A. Tiffith',
#      'damDynamic': None,
#      'damThumbnail': None}}]}]

# %%
for i in info:
    print('Winner:' if i['isWinner'] else 'Nominee:', i['title'], "-", (lambda s: re.search(r'\((.*?)\)', s).group(1) if re.search(r'\((.*?)\)', s) else None)(i['displayLine3']))
# Out:
# Winner: This Is America - Childish Gambino
# Nominee: Shallow - Lady Gaga & Bradley Cooper
# Nominee: The Middle - Zedd, Maren Morris & Grey
# Nominee: The Joke - Brandi Carlile
# Nominee: In My Blood - Shawn Mendes
# Nominee: God's Plan - Drake
# Nominee: Boo'd Up - Ella Mai
# Nominee: All The Stars - Kendrick Lamar & SZA

# %%
from lyricsgenius import Genius
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv
import os
import time

# %%
load_dotenv()
GENIUS_API_KEY = os.getenv('GENIUS_API_KEY')
SPOTIFY_CLIENT_ID = os.getenv('SPOTIFY_CLIENT_ID')
SPOTIFY_CLIENT_SECRET = os.getenv('SPOTIFY_CLIENT_SECRET')

# %%
genius = Genius(GENIUS_API_KEY,
                skip_non_songs=True,
                remove_section_headers=True,
                verbose=False,
                sleep_time=1,
                retries=3
            )

def get_song(name, artist=None):
    pattern = r'^[\s\S]*?Lyrics\s*|(\d*)Embed$|See.*Live|Get tickets.*?\$[\d,]+|You might also like'
    song = genius.search_song(name, artist) if artist else genius.search_song(name)
    return re.sub(pattern, '', song.lyrics, flags=re.MULTILINE)

def get_song_alt(name, artist):
    try:
        return requests.get(f"https://api.lyrics.ovh/v1/{artist}/{name}", timeout=10).json()["lyrics"]
    except requests.Timeout:
        return ""

# %%
empty = {
    'danceability': None,
    'energy': None,
    'key': None,
    'loudness': None,
    'mode': None,
    'speechiness': None,
    'acousticness': None,
    'instrumentalness': None,
    'liveness': None,
    'valence': None,
    'tempo': None,
    'duration_ms': None,
    'time_signature': None
}

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=SPOTIFY_CLIENT_ID, 
                                                           client_secret=SPOTIFY_CLIENT_SECRET),
                    requests_timeout=15, retries=5)

def get_audio_features(song_name, artist_name):

    results = sp.search(q=f'track:{song_name} artist:{artist_name}', type='track', limit=1)
    if results['tracks']['items']:
        track = results['tracks']['items'][0]
        track_id = track['id']
        
        audio_features = sp.audio_features(track_id)
        
        if audio_features:
            audio_features = audio_features[0]
            audio_features.pop('analysis_url')
            audio_features.pop('track_href')
            audio_features.pop('id')
            audio_features.pop('uri')
            audio_features.pop('type')
            return audio_features
        
    return empty

# %%
awards = awards.sample(10)

# %%
import dask.dataframe as dd
from dask.diagnostics import ProgressBar

# Convert Pandas DataFrame to Dask DataFrame
# Parallelize for faster computation
ddf = dd.from_pandas(awards, npartitions=4)

# %%
def make_dataset(awards):
    df = []

    total = awards.shape[0]
    current = 0

    # for each row in the database
    for index, row in awards.iterrows():
        current += 1
        # get the url and use beautiful soup to capture
        
        # print(f"Now at the {row["Edition"]} Grammys. {current}/{total} complete", end='\r', flush=True)

        url = row["url"]
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')

        # extract the soty data
        data = soup.find('script', id="__NEXT_DATA__" ,type="application/json")
        data = json.loads(data.string)

        # extract show year
        year = data["props"]["pageProps"]["pageContent"]["getAwardsYears"]["hits"][0]["showYear"]
        
        # extract the nominees
        categories = data["props"]["pageProps"]["pageContent"]["getAwardsYears"]["hits"][0]["categoryDetails"]

        # get the song of the year category
        info = None
        for category in categories:
            if "song of the year" in category["title"][0]['name'].lower():
                info = category["nominations"]
                break
        
        if info:
            for i in info:
                status = 'Winner' if i['isWinner'] else 'Nominee' 
                
                remove_extra = r"(\s*[\(\[](?:.*?(?:Adapted|Theme|Single|Track|Album|Motion Picture|Film).*?)[\)\]]|-\s*(?=.*?(?:Adapted|Theme|Single|Track|Album|Motion Picture|Film)).*)"
                song = re.sub(r'\s*(\((Single|Track|Album)\))\s', '', i['title'])
                song = re.sub(remove_extra, '', song)
                song = re.sub(r'[\r\t\n]+', '', song)

                try:
                    extract = r'(songwriters|songwriter)\s*\(([^)]+)\)'
                    artist = (lambda s: re.search(extract, s).group(2) if re.search(extract, s) else re.search(r'\((.*?)\)', s).group(1))(i['displayLine3']) 
                    artist = re.sub(r"(?i)(\b(?:feat|featuring|ft|&|and|with)\b.*)|((,|\(|&|\[|(- Various Artists)).*$)", "", artist, flags=re.MULTILINE).strip()
                    artist = re.sub(r"(BeyoncÃ©)", "Beyonce", artist, flags=re.MULTILINE).strip()
                    artist = re.sub(r'[\r\t\n]+', '', artist)
                except:
                    print(row["Edition"], song)

                lyrics = None
                try:
                        lyrics = get_song(song, artist)
                except Exception as e:
                    try:
                        lyrics = get_song_alt(song, artist)
                        print(f"\nTrying alt lyrics for {song} by {artist}")
                    except:
                        print("\nThe alt also failed")
                    # print(e)
                    pass
                
                features = empty
                try:
                    features = get_audio_features(song, artist)
                    pass
                except Exception as e:
                    print(f"\nAn error occured getting audio features for {song} by {artist}")
                    print(e)
                    pass
                
                new_row = {
                    "edition": row["Edition"],
                    "year": year,
                    "status": status,
                    "name": song,
                    "artist": artist,
                    "lyrics": lyrics
                }

                new_row.update(features)

                df.append(new_row)
            
                time.sleep(4)
    
        time.sleep(4)
            
    return pd.DataFrame(df)

# %%
with ProgressBar():
    columns = ["edition", "year", "status", "name", "artist", "lyrics", 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']
    result_ddf = ddf.map_partitions(make_dataset, meta=pd.DataFrame(columns=columns))
    final_df = result_ddf.compute()
# Out:
# [                                        ] | 0% Completed | 356.00 us

# %%
# Old code, without parallelization

# final_df = make_dataset(awards)
# final_df.head()

# %%
# final_df.loc[final_df["name"] == "Theme From Exodus", "lyrics"] = ""

# %%
final_df.head()
# Out:
#   edition  year   status                              name  \
# 0     5th  1962   Winner            What Kind Of Fool Am I
# 1     5th  1962  Nominee               The Sweetest Sounds
# 2     5th  1962  Nominee                  My Coloring Book
# 3     5th  1962  Nominee  I Left My Heart In San Francisco
# 4     5th  1962  Nominee            As Long As He Needs Me
#
#                               artist  \
# 0                        Sammy Davis
# 1                          Peggy Lee
# 2                      Sandy Stewart
# 3                       Tony Bennett
# 4  Shirley Bassey and by Della Reese
#
#                                               lyrics  danceability  energy  \
# 0  What kind of fool am I\nWho never fell in love...         0.231   0.310
# 1  The sweetest sounds I'll ever hear\nAre still ...         0.436   0.453
# 2  For those who fancy colouring books\nAnd lots ...           NaN     NaN
# 3  The loveliness of Paris seems somehow sadly ga...         0.313   0.078
# 4  #\n03' Adolescence - J. Cole\n100 Degrees - Ri...           NaN     NaN
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0  11.0    -8.959   0.0       0.0301         0.960          0.000134
# 1   5.0   -13.835   1.0       0.1560         0.892          0.000000
# 2   NaN       NaN   NaN          NaN           NaN               NaN
# 3   0.0   -17.583   1.0       0.0332         0.955          0.000004
# 4   NaN       NaN   NaN          NaN           NaN               NaN
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0     0.383    0.161   94.009     202617.0             4.0
# 1     0.949    0.611  152.920     101602.0             4.0
# 2       NaN      NaN      NaN          NaN             NaN
# 3     0.169    0.125  128.065     170960.0             4.0
# 4       NaN      NaN      NaN          NaN             NaN

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 0 to 17
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   edition           61 non-null     object
#  1   year              61 non-null     int64
#  2   status            61 non-null     object
#  3   name              61 non-null     object
#  4   artist            61 non-null     object
#  5   lyrics            61 non-null     object
#  6   danceability      59 non-null     float64
#  7   energy            59 non-null     float64
#  8   key               59 non-null     float64
#  9   loudness          59 non-null     float64
#  10  mode              59 non-null     float64
#  11  speechiness       59 non-null     float64
#  12  acousticness      59 non-null     float64
#  13  instrumentalness  59 non-null     float64
#  14  liveness          59 non-null     float64
#  15  valence           59 non-null     float64
#  16  tempo             59 non-null     float64
#  17  duration_ms       59 non-null     float64
#  18  time_signature    59 non-null     float64
# dtypes: float64(13), int64(1), object(5)
# memory usage: 9.5+ KB

# %%
final_df.to_excel('lyrics-dataset.xlsx', index=False, engine='openpyxl')

# %%
final_df.sample(5)
# Out:
#   edition  year   status                                name  \
# 9    64th  2021  Nominee                             Peaches
# 6    19th  1976  Nominee  The Wreck Of The Edmund Fitzgerald
# 5    36th  1993  Nominee                 The River Of Dreams
# 5    19th  1976  Nominee                     This Masquerade
# 1    35th  1992  Nominee              Save The Best For Last
#
#              artist                                             lyrics  \
# 9     Justin Bieber  I got my peaches out in Georgia (Oh, yeah, shi...
# 6  Gordon Lightfoot  The legend lives on from the Chippewa on down\...
# 5        Billy Joel  In the middle of the, I go walking in the\nIn ...
# 5     George Benson  ​\nAre we really happy here with this lonely g...
# 1  Vanessa Williams  Sometimes the snow comes down in June\nSometim...
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 9         0.677   0.696  0.0    -6.181   1.0       0.1190         0.321
# 6         0.308   0.376  4.0   -15.240   1.0       0.0626         0.116
# 5         0.631   0.749  7.0    -8.150   1.0       0.0576         0.205
# 5         0.625   0.373  5.0   -12.549   0.0       0.0383         0.500
# 1         0.528   0.234  3.0   -15.784   1.0       0.0283         0.641
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 9          0.000000    0.4200    0.464   90.030     198082.0             4.0
# 6          0.000003    0.1660    0.158  186.047     389280.0             3.0
# 5          0.000005    0.0667    0.437   89.646     247627.0             4.0
# 5          0.000524    0.1320    0.430   88.543     483133.0             4.0
# 1          0.000000    0.1830    0.191   95.911     218733.0             4.0
