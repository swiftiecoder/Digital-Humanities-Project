# %%
import pandas as pd

# %%
old = pd.read_excel('lyrics-dataset-updated.xlsx')
more = pd.read_csv('brat/new-dataset.csv')

# %%
old.head()
# Out:
#   edition  year   status                       name         artist  \
# 0     3rd  1960   Winner          Theme From Exodus    Ernest Gold
# 1     3rd  1960  Nominee  Theme From A Summer Place    Percy Faith
# 2     3rd  1960  Nominee         Second Time Around  Frank Sinatra
# 3     3rd  1960  Nominee               Nice 'n Easy  Frank Sinatra
# 4     3rd  1960  Nominee           He'll Have To Go     Jim Reeves
#
#                                               lyrics  danceability  energy  \
# 0                                                NaN        0.0846   0.265
# 1                                                NaN        0.3260   0.326
# 2  Love is lovelier the second time around\nJust ...        0.2530   0.193
# 3  Let's take it nice and easy\nIt's gonna be so ...        0.5360   0.148
# 4  Put your sweet lips a little closer to the pho...        0.5670   0.168
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
old.shape
# Out:
# (347, 19)

# %%
more.rename(columns={'track': 'name'}, inplace=True)
more["edition"] = "67th"
more.head()
# Out:
#                  name          artist  \
# 0     Good Luck Babe!   Chappell Roan
# 1         Not Like Us  Kendrick Lamar
# 2           Fortnight    Taylor Swift
# 3  A Bar Song (Tipsy)       Shaboozey
# 4  Birds of a Feather   Billie Eilish
#
#                                               lyrics  danceability  energy  \
# 0  It's fine, it's cool\nYou can say that we are ...         0.700   0.582
# 1  Psst, I see dead people\n(Mustard on the beat,...         0.898   0.472
# 2  I was supposed to be sent away\nBut they forgo...         0.504   0.386
# 3  My baby want a Birkin, she's been tellin' me a...         0.722   0.709
# 4  I want you to stay\n'Til I'm in the grave\n'Ti...         0.747   0.507
#
#     key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0  11.0    -5.960   0.0       0.0356        0.0502          0.000000
# 1   1.0    -7.001   1.0       0.0776        0.0107          0.000000
# 2  11.0   -10.976   1.0       0.0308        0.5020          0.000015
# ...

# %%
combined_df = pd.concat([old, more], axis=0, ignore_index=True)
combined_df.shape
# Out:
# (355, 19)

# %%
combined_df
# Out:
#     edition  year   status                       name                  artist  \
# 0       3rd  1960   Winner          Theme From Exodus             Ernest Gold
# 1       3rd  1960  Nominee  Theme From A Summer Place             Percy Faith
# 2       3rd  1960  Nominee         Second Time Around           Frank Sinatra
# 3       3rd  1960  Nominee               Nice 'n Easy           Frank Sinatra
# 4       3rd  1960  Nominee           He'll Have To Go              Jim Reeves
# ..      ...   ...      ...                        ...                     ...
# 350    67th  2025  Nominee         A Bar Song (Tipsy)               Shaboozey
# 351    67th  2025  Nominee         Birds of a Feather           Billie Eilish
# 352    67th  2025  Nominee           Die With a Smile  Lady Gaga & Bruno Mars
# 353    67th  2025  Nominee       Please Please Please       Sabrina Carpenter
# 354    67th  2025  Nominee             Texas Hold 'Em                 Beyoncé
#
# ...

# %%
combined_df.to_excel('lyrics-dataset-updated-v2.xlsx', index=False)
